# %% [markdown]
# Threshold based resource allocation algorithm

# %%
import pandas as pd

import matplotlib.pyplot as plot


data = {"Threshold based":[40, 40, 21],

        "Optimal container based":[33, 34, 34]

        };

index     = ["vm1", "vm2", "vm3"];
      

containerAllocation = pd.DataFrame(data=data, index=index);

containerAllocation.plot.bar(rot=15, title="Comparision of number of containers allocated to each VM based on two algorithms");

plot.show(block=True);
